# %%
import time
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import DBSCAN

from Cluster import Cluster
from IncDBSCAN import IncrementalDBSCAN
from DatasetPattern import DatasetPattern
from utils import initDataset

from sklearn import metrics
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler

# %%
centers = [[1, 1], [-1, -1], [1, -1], [-1, 1]]
X, labels_true = make_blobs(
    n_samples=1000, centers=centers, cluster_std=1, random_state=24
)

X = StandardScaler().fit_transform(X)

# %%
X_del = X[:750]
X_add = X[750:]
print(len(X_add))
print(len(X_del))
# Out:
# 300
# 700

# %%
start_time = time.time()
db = DBSCAN(eps=0.3, min_samples=10).fit(X_add)
#core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
#core_samples_mask[db.core_sample_indices_] = True
labels = db.labels_
elapsed_time = time.time() - start_time
print("elapsed_time: {}[sec]".format(elapsed_time))
# Out:
# elapsed_time: 0.0014612674713134766[sec]

# %%
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)

print("Estimated number of clusters: %d" % n_clusters_)
print("Estimated number of noise points: %d" % n_noise_)
#print("Homogeneity: %0.3f" % metrics.homogeneity_score(labels_true, labels))
#print("Completeness: %0.3f" % metrics.completeness_score(labels_true, labels))
#print("V-measure: %0.3f" % metrics.v_measure_score(labels_true, labels))
#print("Adjusted Rand Index: %0.3f" % metrics.adjusted_rand_score(labels_true, labels))
#print(
#    "Adjusted Mutual Information: %0.3f"
#    % metrics.adjusted_mutual_info_score(labels_true, labels)
#)
#print("Silhouette Coefficient: %0.3f" % metrics.silhouette_score(X, labels))
# Out:
# Estimated number of clusters: 2
# Estimated number of noise points: 133

# %%
fig = plt.figure(figsize=(12.0, 12.0))
unique_labels = set(labels)
colors = [plt.cm.Spectral(each) for each in np.linspace(0, 1, len(unique_labels))]
for k, col in zip(unique_labels, colors):
    if k == -1:
        # Black used for noise.
        col = [0, 0, 0, 1]

    class_member_mask = labels == k

    xy = X_add[class_member_mask]
    plt.plot(
        xy[:, 0],
        xy[:, 1],
        "o",
        markerfacecolor=tuple(col),
        markeredgecolor="k",
        markersize=8,
    )

plt.title("Estimated number of clusters: %d" % n_clusters_)
plt.show()

# %%
X_add2 = X_add[3:]
db = DBSCAN(eps=0.3, min_samples=10).fit(X_add2)
#core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
#core_samples_mask[db.core_sample_indices_] = True
labels2 = db.labels_
fig = plt.figure(figsize=(12.0, 12.0))
unique_labels2 = set(labels2)
colors2 = [plt.cm.Spectral(each) for each in np.linspace(0, 1, len(unique_labels2))]
for k, col in zip(unique_labels2, colors2):
    if k == -1:
        # Black used for noise.
        col = [0, 0, 0, 1]

    class_member_mask2 = labels2 == k

    xy = X_add2[class_member_mask2]
    plt.plot(
        xy[:, 0],
        xy[:, 1],
        "o",
        markerfacecolor=tuple(col),
        markeredgecolor="k",
        markersize=8,
    )

plt.title("Estimated number of clusters: %d" % n_clusters_)
plt.show()

# %%
#np.random.shuffle(X)
Xinc = initDataset(X)
start_time = time.time()
incDBSCAN = IncrementalDBSCAN(minpts=10,eps=0.3)
for p in Xinc:
    clu = incDBSCAN.fit(p)
for i in range(750):
    print("remove: {}".format(i))
    #from IPython.core.debugger import Pdb; Pdb().set_trace()
    incDBSCAN.remove(i)
    print()
elapsed_time = time.time() - start_time
clustersList = incDBSCAN.getClustersList()
print("Incremental DBSCAN Results")
print("==========================")
print("")
incDBSCAN.printClustersInformation()
print("")
print("Runtime = {}[sec]".format(elapsed_time))
print("EPS = {}".format(0.3))
print("Minpts = {}".format(10))
# Out:
# remove: 0
#
# Nonsplit Reduction
# assigned cluster: 7
#
# remove:
#
# Nonsplit Reduction
# assigned cluster: 7
#
# remove: 249
# Removal
#
# remove: 250
#
# Nonsplit Reduction
# assigned cluster: 7
#
# remove: 251
#
# Nonsplit Reduction
# assigned cluster: 7
#
# remove: 252
#
# Nonsplit Reduction
# assigned cluster: 7
#
# remove: 253
# Removal
#
# remove: 254
#
# Nonsplit Reduction
# assigned cluster: 7
#
# remove: 255
#
# Nonsplit Reduction
# assigned cluster: 7
#
# remove: 256
#
# Nonsplit Reduction
# assigned cluster: 7
#
# remove: 257
#
# Nonsplit Reduction
# assigned cluster: 7
#
# remove: 258
#
# Nonsplit Reduction
# assigned cluster: 7
#
# remove: 259
#
# Nonsplit Reduction
# assigned cluster: 7
#
# remove: 260
#
# Nonsplit Reduction
# assigned cluster: 7
#
# remove: 261
#
# Nonsplit Reduction
# assigned cluster: 7
#
# remove: 262
# Removal
#
# remove: 263
#
# Nonsplit Reduction
# assigned cluster: 7
#
# remove: 264
#
# Split
#
# remove: 265
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 266
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 267
# Removal
#
# remove: 268
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 269
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 270
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 271
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 272
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 273
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 274
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 275
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 276
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 277
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 278
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 279
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 280
# Reduction
# assigned cluster: 23
#
# remove: 281
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 282
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 283
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 284
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 285
# Removal
#
# remove: 286
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 287
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 288
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 289
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 290
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 291
# Reduction
# assigned cluster: 23
#
# remove: 292
# Removal
#
# remove: 293
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 294
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 295
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 296
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 297
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 298
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 299
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 300
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 301
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 302
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 303
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 304
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 305
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 306
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 307
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 308
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 309
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 310
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 311
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 312
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 313
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 314
# Removal
#
# remove: 315
# Reduction
# assigned cluster: 23
#
# remove: 316
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 317
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 318
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 319
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 320
# Removal
#
# remove: 321
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 322
# Removal
#
# remove: 323
# Removal
#
# remove: 324
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 325
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 326
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 327
# Removal
#
# remove: 328
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 329
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 330
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 331
#
# Nonsplit Reduction
# assigned cluster: 23
#
# remove: 332
#
# Split
#
# remove: 333
# Removal
#
# remove: 334
#
# Nonsplit Reduction
# assigned cluster: 33
#
# remove: 335
#
# Nonsplit Reduction
# assigned cluster: 33
#
# remove: 336
#
# Nonsplit Reduction
# assigned cluster: 33
#
# remove: 337
#
# Nonsplit Reduction
# assigned cluster: 33
#
# remove: 338
#
# Nonsplit Reduction
# assigned cluster: 33
#
# remove: 339
#
# Nonsplit Reduction
# assigned cluster: 33
#
# remove: 340
#
# Nonsplit Reduction
# assigned cluster: 33
#
# remove: 341
#
# Nonsplit Reduction
# assigned cluster: 33
#
# remove: 342
#
# Nonsplit Reduction
# assigned cluster: 33
#
# remove: 343
#
# Nonsplit Reduction
# assigned cluster: 33
#
# remove: 344
#
# Nonsplit Reduction
# assigned cluster: 33
#
# remove: 345
#
# Nonsplit Reduction
# assigned cluster: 33
#
# remove: 346
#
# Nonsplit Reduction
# assigned cluster: 33
#
# remove: 347
# Removal
#
# remove: 348
#
# Nonsplit Reduction
# assigned cluster: 33
#
# remove: 349
#
# Split
#
# remove: 350
#
# Nonsplit Reduction
# assigned cluster: 44
#
# remove: 351
#
# Nonsplit Reduction
# assigned cluster: 44
#
# remove: 352
# Removal
#
# remove: 353
#
# Nonsplit Reduction
# assigned cluster: 44
#
# remove: 354
#
# Nonsplit Reduction
# assigned cluster: 44
#
# remove: 355
#
# Nonsplit Reduction
# assigned cluster: 44
#
# remove: 356
# Reduction
# assigned cluster: 44
#
# remove: 357
#
# Nonsplit Reduction
# assigned cluster: 44
#
# remove: 358
#
# Split
#
# remove: 359
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 360
# Reduction
# assigned cluster: 59
#
# remove: 361
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 362
# Reduction
# assigned cluster: 59
#
# remove: 363
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 364
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 365
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 366
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 367
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 368
# Removal
#
# remove: 369
# Reduction
# assigned cluster: 56
#
# remove: 370
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 371
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 372
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 373
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 374
# Reduction
# assigned cluster: 59
#
# remove: 375
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 376
# Removal
#
# remove: 377
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 378
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 379
# Removal
#
# remove: 380
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 381
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 382
# Reduction
# assigned cluster: 59
#
# remove: 383
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 384
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 385
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 386
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 387
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 388
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 389
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 390
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 391
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 392
# Reduction
# assigned cluster: 59
#
# remove: 393
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 394
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 395
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 396
# Reduction
# assigned cluster: 59
#
# remove: 397
# Removal
#
# remove: 398
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 399
# Removal
#
# remove: 400
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 401
# Reduction
# assigned cluster: 59
#
# remove: 402
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 403
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 404
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 405
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 406
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 407
# Reduction
# assigned cluster: 56
#
# remove: 408
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 409
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 410
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 411
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 412
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 413
# Removal
#
# remove: 414
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 415
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 416
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 417
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 418
# Reduction
# assigned cluster: 59
#
# remove: 419
# Removal
#
# remove: 420
# Reduction
# assigned cluster: 59
#
# remove: 421
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 422
# Reduction
# assigned cluster: 59
#
# remove: 423
# Reduction
# assigned cluster: 56
#
# remove: 424
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 425
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 426
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 427
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 428
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 429
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 430
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 431
# Removal
#
# remove: 432
#
# Nonsplit Reduction
# assigned cluster: 59
#
# remove: 433
#
# Split
#
# remove: 434
# Removal
#
# remove: 435
#
# Nonsplit Reduction
# assigned cluster: 71
#
# remove: 436
#
# Nonsplit Reduction
# assigned cluster: 71
#
# remove: 437
#
# Nonsplit Reduction
# assigned cluster: 71
#
# remove: 438
# Removal
#
# remove: 439
#
# Nonsplit Reduction
# assigned cluster: 71
#
# remove: 440
# Removal
#
# remove: 441
#
# Nonsplit Reduction
# assigned cluster: 71
#
# remove: 442
#
# Nonsplit Reduction
# assigned cluster: 71
#
# remove: 443
#
# Nonsplit Reduction
# assigned cluster: 71
#
# remove: 444
#
# Nonsplit Reduction
# assigned cluster: 71
#
# remove: 445
# Removal
#
# remove: 446
#
# Nonsplit Reduction
# assigned cluster: 71
#
# remove: 447
#
# Nonsplit Reduction
# assigned cluster: 71
#
# remove: 448
#
# Nonsplit Reduction
# assigned cluster: 71
#
# remove: 449
# Reduction
# assigned cluster: 71
#
# remove: 450
#
# Nonsplit Reduction
# assigned cluster: 71
#
# remove: 451
# Removal
#
# remove: 452
#
# Nonsplit Reduction
# assigned cluster: 71
#
# remove: 453
#
# Nonsplit Reduction
# assigned cluster: 71
#
# remove: 454
# Removal
#
# remove: 455
#
# Nonsplit Reduction
# assigned cluster: 71
#
# remove: 456
# Removal
# pattern assigned cluster: 67
# pattern iscore: False
# pattern neighbors: [493, 531, 612, 834, 942]
# exists core point in the neighbors: False
# number of points in the cluster: 7
# vanish cluster ID: 67
# cluster points: {612, 836, 711, 456, 493, 498, 531}
# [<Cluster.Cluster object at 0x7f21d7b6e898>, <Cluster.Cluster object at 0x7f224c0aaf28>, <Cluster.Cluster object at 0x7f21d7aa8d68>, <Cluster.Cluster object at 0x7f21d7aa8d30>, <Cluster.Cluster object at 0x7f21d7aa8dd8>, <Cluster.Cluster object at 0x7f21d7aa8e10>, <Cluster.Cluster object at 0x7f21d7aa8e48>, <Cluster.Cluster object at 0x7f21d7aa8e80>, <Cluster.Cluster object at 0x7f21d7aa8eb8>, <Cluster.Cluster object at 0x7f21d7aa8ef0>, <Cluster.Cluster object at 0x7f21d7aa8f28>, <Cluster.Cluster object at 0x7f21d7aa8f98>, <Cluster.Cluster object at 0x7f21d7aa8fd0>, <Cluster.Cluster object at 0x7f21d7a7d048>, <Cluster.Cluster object at 0x7f21d7a7d080>, <Cluster.Cluster object at 0x7f21d7a7d0b8>, <Cluster.Cluster object at 0x7f21d7a7d0f0>, <Cluster.Cluster object at 0x7f21d7a7d128>, <Cluster.Cluster object at 0x7f21d7a7d160>, <Cluster.Cluster object at 0x7f21d7a7d198>, <Cluster.Cluster object at 0x7f21d7a7d1d0>, <Cluster.Cluster object at 0x7f21d7a7d208>, <Cluster.Cluster object at 0x7f21d7a7d240>, <Cluster.Cluster object at 0x7f21d7a7d278>, <Cluster.Cluster object at 0x7f21d7a7d2e8>, <Cluster.Cluster object at 0x7f21d7a7d320>, <Cluster.Cluster object at 0x7f21d7a7d358>, <Cluster.Cluster object at 0x7f21d7a7d390>, <Cluster.Cluster object at 0x7f21d7a7d3c8>, <Cluster.Cluster object at 0x7f21d7a7d400>, <Cluster.Cluster object at 0x7f21d7a7d438>, <Cluster.Cluster object at 0x7f21d7a7d470>, <Cluster.Cluster object at 0x7f21d7a7d4a8>, <Cluster.Cluster object at 0x7f21d7a7d4e0>, <Cluster.Cluster object at 0x7f21d7a7d518>, <Cluster.Cluster object at 0x7f21d7a7d550>, <Cluster.Cluster object at 0x7f21d7a7d588>, <Cluster.Cluster object at 0x7f21d7a7d5c0>, <Cluster.Cluster object at 0x7f21d7a7d5f8>, <Cluster.Cluster object at 0x7f21d7a7d630>, <Cluster.Cluster object at 0x7f21d7a7d668>, <Cluster.Cluster object at 0x7f21d7a7d6a0>, <Cluster.Cluster object at 0x7f21d7a7d6d8>, <Cluster.Cluster object at 0x7f21d7a7d710>, <Cluster.Cluster object at 0x7f21d7a7d748>, <Cluster.Cluster object at 0x7f21d7a7d7b8>, <Cluster.Cluster object at 0x7f21d7a7d828>, <Cluster.Cluster object at 0x7f21d7a7d860>, <Cluster.Cluster object at 0x7f21d7a7d8d0>, <Cluster.Cluster object at 0x7f21d7a7d898>, <Cluster.Cluster object at 0x7f21d7a7d908>, <Cluster.Cluster object at 0x7f21d7a7d940>, <Cluster.Cluster object at 0x7f21d7a7d978>, <Cluster.Cluster object at 0x7f21d7a7d9b0>, <Cluster.Cluster object at 0x7f21d7a7d9e8>, <Cluster.Cluster object at 0x7f21d7a7da20>, <Cluster.Cluster object at 0x7f21d7a7da58>, <Cluster.Cluster object at 0x7f21d7a7da90>, <Cluster.Cluster object at 0x7f21d7a7dac8>, <Cluster.Cluster object at 0x7f21d7a7db00>, <Cluster.Cluster object at 0x7f21d7a7dba8>, <Cluster.Cluster object at 0x7f21d7a7d7f0>, <Cluster.Cluster object at 0x7f21d7a7dc50>, <Cluster.Cluster object at 0x7f21d7a7dc88>, <Cluster.Cluster object at 0x7f21d7a7dcc0>, <Cluster.Cluster object at 0x7f21d7a7dcf8>, <Cluster.Cluster object at 0x7f21d7a7dd30>, <Cluster.Cluster object at 0x7f21d7a7dd68>, <Cluster.Cluster object at 0x7f21d7a7dda0>, <Cluster.Cluster object at 0x7f21d7a7ddd8>, <Cluster.Cluster object at 0x7f21d7a7de10>, <Cluster.Cluster object at 0x7f21d7a7de48>]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# cluster vanished!
# pattern ID: 456
#
#
# remove: 457
#
# Nonsplit Reduction
# assigned cluster: 71
#
# remove: 458
#
# Nonsplit Reduction
# assigned cluster: 71
#
# remove: 459
# Reduction
# assigned cluster: 71
#
# remove: 460
#
# Nonsplit Reduction
# assigned cluster: 71
#
# remove: 461
#
# Nonsplit Reduction
# assigned cluster: 71
#
# remove: 462
#
# Nonsplit Reduction
# assigned cluster: 71
#
# remove: 463
#
# Nonsplit Reduction
# assigned cluster: 71
#
# remove: 464
#
# Nonsplit Reduction
# assigned cluster: 71
#
# remove: 465
#
# Nonsplit Reduction
# assigned cluster: 71
#
# remove: 466
#
# Nonsplit Reduction
# assigned cluster: 71
#
# remove: 467
#
# Nonsplit Reduction
# assigned cluster: 71
#
# remove: 468
#
# Nonsplit Reduction
# assigned cluster: 71
#
# remove: 469
#
# Nonsplit Reduction
# assigned cluster: 71
#
# remove: 470
#
# Nonsplit Reduction
# assigned cluster: 71
#
# remove: 471
# Removal
#
# remove: 472
#
# Nonsplit Reduction
# assigned cluster: 71
#
# remove: 473
# Removal
#
# remove: 474
# Removal
#
# remove: 475
#
# Nonsplit Reduction
# assigned cluster: 71
#
# remove: 476
# Removal
#
# remove: 477
# Removal
#
# remove: 478
# Removal
#
# remove: 479
#
# Nonsplit Reduction
# assigned cluster: 71
#
# remove: 480
#
# Nonsplit Reduction
# assigned cluster: 71
#
# remove: 481
#
# Nonsplit Reduction
# assigned cluster: 71
#
# remove: 482
#
# Nonsplit Reduction
# assigned cluster: 71
#
# remove: 483
#
# Nonsplit Reduction
# assigned cluster: 71
#
# remove: 484
# Reduction
# assigned cluster: 56
#
# remove: 485
#
# Nonsplit Reduction
# assigned cluster: 71
#
# remove: 486
#
# Nonsplit Reduction
# assigned cluster: 71
#
# remove: 487
#
# Nonsplit Reduction
# assigned cluster: 71
#
# remove: 488
# Removal
#
# remove: 489
# Reduction
# assigned cluster: 71
#
# remove: 490
#
# Nonsplit Reduction
# assigned cluster: 71
#
# remove: 491
#
# Nonsplit Reduction
# assigned cluster: 71
#
# remove: 492
#
# Nonsplit Reduction
# assigned cluster: 71
#
# remove: 493
# Removal
#
# remove: 494
#
# Nonsplit Reduction
# assigned cluster: 71
#
# remove: 495
# Removal
#
# remove: 496
# Removal
#
# remove: 497
#
# Nonsplit Reduction
# assigned cluster: 71
#
# remove: 498
# Removal
#
# remove: 499
#
# Nonsplit Reduction
# assigned cluster: 71
#
# remove: 500
#
# Split
#
# remove: 501
#
# Nonsplit Reduction
# assigned cluster: 76
#
# remove: 502
#
# Nonsplit Reduction
# assigned cluster: 76
#
# remove: 503
# Removal
#
# remove: 504
#
# Nonsplit Reduction
# assigned cluster: 76
#
# remove: 505
#
# Nonsplit Reduction
# assigned cluster: 76
#
# remove: 506
#
# Nonsplit Reduction
# assigned cluster: 76
#
# remove: 507
#
# Nonsplit Reduction
# assigned cluster: 76
#
# remove: 508
# Removal
#
# remove: 509
#
# Nonsplit Reduction
# assigned cluster: 76
#
# remove: 510
#
# Nonsplit Reduction
# assigned cluster: 76
#
# remove: 511
# Removal
#
# remove: 512
#
# Nonsplit Reduction
# assigned cluster: 76
#
# remove: 513
#
# Nonsplit Reduction
# assigned cluster: 76
#
# remove: 514
#
# Split
#
# remove: 515
#
# Split
#
# remove: 516
#
# Nonsplit Reduction
# assigned cluster: 93
#
# remove: 517
# Reduction
# assigned cluster: 92
#
# remove: 518
#
# Nonsplit Reduction
# assigned cluster: 93
#
# remove: 519
#
# Nonsplit Reduction
# assigned cluster: 93
#
# remove: 520
#
# Nonsplit Reduction
# assigned cluster: 93
#
# remove: 521
# Reduction
# assigned cluster: 84
#
# remove: 522
# Reduction
# assigned cluster: 93
#
# remove: 523
#
# Nonsplit Reduction
# assigned cluster: 93
#
# remove: 524
# Removal
#
# remove: 525
# Removal
#
# remove: 526
#
# Nonsplit Reduction
# assigned cluster: 93
#
# remove: 527
#
# Nonsplit Reduction
# assigned cluster: 93
#
# remove: 528
#
# Nonsplit Reduction
# assigned cluster: 93
#
# remove: 529
# Reduction
# assigned cluster: 84
#
# remove: 530
# Removal
#
# remove: 531
# Removal
#
# remove: 532
#
# Nonsplit Reduction
# assigned cluster: 93
#
# remove: 533
#
# Nonsplit Reduction
# assigned cluster: 93
#
# remove: 534
#
# Nonsplit Reduction
# assigned cluster: 93
#
# remove: 535
# Reduction
# assigned cluster: 93
#
# remove: 536
# Removal
#
# remove: 537
# Reduction
# assigned cluster: 56
#
# remove: 538
#
# Nonsplit Reduction
# assigned cluster: 93
#
# remove: 539
# Removal
#
# remove: 540
# Reduction
# assigned cluster: 93
#
# remove: 541
#
# Nonsplit Reduction
# assigned cluster: 93
#
# remove: 542
#
# Nonsplit Reduction
# assigned cluster: 93
#
# remove: 543
# Reduction
# assigned cluster: 93
#
# remove: 544
#
# Nonsplit Reduction
# assigned cluster: 93
#
# remove: 545
#
# Nonsplit Reduction
# assigned cluster: 93
#
# remove: 546
#
# Nonsplit Reduction
# assigned cluster: 93
#
# remove: 547
#
# Nonsplit Reduction
# assigned cluster: 93
#
# remove: 548
# Removal
#
# remove: 549
#
# Nonsplit Reduction
# assigned cluster: 93
#
# remove: 550
#
# Nonsplit Reduction
# assigned cluster: 93
#
# remove: 551
#
# Nonsplit Reduction
# assigned cluster: 93
#
# remove: 552
#
# Nonsplit Reduction
# assigned cluster: 93
#
# remove: 553
#
# Nonsplit Reduction
# assigned cluster: 93
#
# remove: 554
# Removal
#
# remove: 555
# Removal
#
# remove: 556
#
# Nonsplit Reduction
# assigned cluster: 93
#
# remove: 557
# Removal
#
# remove: 558
# Removal
#
# remove: 559
# Reduction
# assigned cluster: 93
#
# remove: 560
# Removal
#
# remove: 561
#
# Nonsplit Reduction
# assigned cluster: 93
#
# remove: 562
#
# Nonsplit Reduction
# assigned cluster: 93
#
# remove: 563
#
# Nonsplit Reduction
# assigned cluster: 93
#
# remove: 564
#
# Split
#
# remove: 565
# Removal
#
# remove: 566
#
# Nonsplit Reduction
# assigned cluster: 101
#
# remove: 567
#
# Nonsplit Reduction
# assigned cluster: 101
#
# remove: 568
#
# Nonsplit Reduction
# assigned cluster: 101
#
# remove: 569
#
# Nonsplit Reduction
# assigned cluster: 101
#
# remove: 570
#
# Nonsplit Reduction
# assigned cluster: 101
#
# remove: 571
# Removal
#
# remove: 572
# Removal
#
# remove: 573
# Removal
#
# remove: 574
#
# Nonsplit Reduction
# assigned cluster: 101
#
# remove: 575
# Reduction
# assigned cluster: 84
#
# remove: 576
# Removal
#
# remove: 577
#
# Nonsplit Reduction
# assigned cluster: 101
#
# remove: 578
# Removal
#
# remove: 579
#
# Nonsplit Reduction
# assigned cluster: 101
#
# remove: 580
# Reduction
# assigned cluster: 97
#
# remove: 581
#
# Nonsplit Reduction
# assigned cluster: 101
#
# remove: 582
#
# Nonsplit Reduction
# assigned cluster: 101
#
# remove: 583
#
# Nonsplit Reduction
# assigned cluster: 101
#
# remove: 584
#
# Nonsplit Reduction
# assigned cluster: 101
#
# remove: 585
# Removal
#
# remove: 586
#
# Nonsplit Reduction
# assigned cluster: 101
#
# remove: 587
# Removal
# pattern assigned cluster: 97
# pattern iscore: False
# pattern neighbors: [631, 653, 673, 781, 819, 901]
# exists core point in the neighbors: False
# number of points in the cluster: 9
# vanish cluster ID: 97
# cluster points: {673, 897, 967, 871, 587, 653, 781, 819, 631}
# [<Cluster.Cluster object at 0x7f21d7b6e898>, <Cluster.Cluster object at 0x7f224c0aaf28>, <Cluster.Cluster object at 0x7f21d7aa8d68>, <Cluster.Cluster object at 0x7f21d7aa8d30>, <Cluster.Cluster object at 0x7f21d7aa8dd8>, <Cluster.Cluster object at 0x7f21d7aa8e10>, <Cluster.Cluster object at 0x7f21d7aa8e48>, <Cluster.Cluster object at 0x7f21d7aa8e80>, <Cluster.Cluster object at 0x7f21d7aa8eb8>, <Cluster.Cluster object at 0x7f21d7aa8ef0>, <Cluster.Cluster object at 0x7f21d7aa8f28>, <Cluster.Cluster object at 0x7f21d7aa8f98>, <Cluster.Cluster object at 0x7f21d7aa8fd0>, <Cluster.Cluster object at 0x7f21d7a7d048>, <Cluster.Cluster object at 0x7f21d7a7d080>, <Cluster.Cluster object at 0x7f21d7a7d0b8>, <Cluster.Cluster object at 0x7f21d7a7d0f0>, <Cluster.Cluster object at 0x7f21d7a7d128>, <Cluster.Cluster object at 0x7f21d7a7d160>, <Cluster.Cluster object at 0x7f21d7a7d198>, <Cluster.Cluster object at 0x7f21d7a7d1d0>, <Cluster.Cluster object at 0x7f21d7a7d208>, <Cluster.Cluster object at 0x7f21d7a7d240>, <Cluster.Cluster object at 0x7f21d7a7d278>, <Cluster.Cluster object at 0x7f21d7a7d2e8>, <Cluster.Cluster object at 0x7f21d7a7d320>, <Cluster.Cluster object at 0x7f21d7a7d358>, <Cluster.Cluster object at 0x7f21d7a7d390>, <Cluster.Cluster object at 0x7f21d7a7d3c8>, <Cluster.Cluster object at 0x7f21d7a7d400>, <Cluster.Cluster object at 0x7f21d7a7d438>, <Cluster.
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# True
# cluster vanished!
# pattern ID: 587
#
#
# remove: 588
#
# Nonsplit Reduction
# assigned cluster: 101
#
# remove: 589
# Reduction
# assigned cluster: 101
#
# remove: 590
# Reduction
# assigned cluster: 101
#
# remove: 591
# Reduction
# assigned cluster: 92
#
# remove: 592
# Removal
#
# remove: 593
#
# Nonsplit Reduction
# assigned cluster: 101
#
# remove: 594
#
# Nonsplit Reduction
# assigned cluster: 101
#
# remove: 595
#
# Nonsplit Reduction
# assigned cluster: 101
#
# remove: 596
#
# Nonsplit Reduction
# assigned cluster: 101
#
# remove: 597
# Removal
#
# remove: 598
# Reduction
# assigned cluster: 101
#
# remove: 599
# Removal
#
# remove: 600
#
# Nonsplit Reduction
# assigned cluster: 101
#
# remove: 601
#
# Nonsplit Reduction
# assigned cluster: 101
#
# remove: 602
#
# Nonsplit Reduction
# assigned cluster: 101
#
# remove: 603
#
# Nonsplit Reduction
# assigned cluster: 101
#
# remove: 604
# Removal
#
# remove: 605
#
# Split
#
# remove: 606
# Reduction
# assigned cluster: 107
#
# remove: 607
# Reduction
# assigned cluster: 92
#
# remove: 608
#
# Nonsplit Reduction
# assigned cluster: 107
#
# remove: 609
#
# Nonsplit Reduction
# assigned cluster: 107
#
# remove: 610
# Removal
#
# remove: 611
#
# Nonsplit Reduction
# assigned cluster: 107
#
# remove: 612
# Removal
#
# remove: 613
# Reduction
# assigned cluster: 107
#
# remove: 614
# Removal
#
# remove: 615
#
# Nonsplit Reduction
# assigned cluster: 107
#
# remove: 616
# Reduction
# assigned cluster: -1
#
# remove: 617
# Reduction
# assigned cluster: 56
#
# remove: 618
# Removal
#
# remove: 619
# Reduction
# assigned cluster: 107
#
# remove: 620
# Reduction
# assigned cluster: 107
#
# remove: 621
#
# Nonsplit Reduction
# assigned cluster: 107
#
# remove: 622
# Reduction
# assigned cluster: 106
#
# remove: 623
# Removal
#
# remove: 624
#
# Nonsplit Reduction
# assigned cluster: 107
#
# remove: 625
# Removal
#
# remove: 626
# Reduction
# assigned cluster: 84
#
# remove: 627
# Removal
# pattern assigned cluster: 92
# pattern iscore: False
# pattern neighbors: [664, 665, 738, 779, 817, 869, 917, 919, 933]
# exists core point in the neighbors: False
# number of points in the cluster: 14
# vanish cluster ID: 92
# cluster points: {779, 916, 660, 917, 919, 664, 665, 933, 817, 964, 714, 738, 869, 627}
# [<Cluster.Cluster object at 0x7f21d7b6e898>, <Cluster.Cluster object at 0x7f224c0aaf28>, <Cluster.Cluster object at 0x7f21d7aa8d68>, <Cluster.Cluster object at 0x7f21d7aa8d30>, <Cluster.Cluster object at 0x7f21d7aa8dd8>, <Cluster.Cluster object at 0x7f21d7aa8e10>, <Cluster.Cluster object at 0x7f21d7aa8e48>, <Cluster.Cluster object at 0x7f21d7aa8e80>, <Cluster.Cluster object at 0x7f21d7aa8eb8>, <Cluster.Cluster object at 0x7f21d7aa8ef0>, <Cluster.Cluster object at 0x7f21d7aa8f28>, <Cluster.Cluster object at 0x7f21d7aa8f98>, <Cluster.Cluster object at 0x7f21d7aa8fd0>, <Cluster.Cluster object at 0x7f21d7a7d048>, <Cluster.Cluster object at 0x7f21d7a7d080>, <Cluster.Cluster object at 0x7f21d7a7d0b8>, <Cluster.Cluster object at 0x7f21d7a7d0f0>, <Cluster.Cluster object at 0x7f21d7a7d128>, <Cluster.Cluster object at 0x7f21d7a7d160>, <Cluster.Cluster object at 0x7f21d7a7d198>, <Cluster.Cluster object at 0x7f21d7a7d1d0>, <Cluster.Cluster object at 0x7f21d7a7d208>, <Cluster.Cluster object at 0x7f21d7a7d240>, <Cluster.Cluster object at 0x7f21d7a7d278>, <Cluster.Cluster object at 0x7f21d7a7d2e8>, <Cluster.Cluster object at 0x7f21d7a7d320>, <Cluster.Cluster object at 0x7f21d7a7d358>, <Cluster.Cluster object at 0x7f21d7a7
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# True
# cluster vanished!
# pattern ID: 627
#
#
# remove: 628
#
# Nonsplit Reduction
# assigned cluster: 107
#
# remove: 629
#
# Nonsplit Reduction
# assigned cluster: 107
#
# remove: 630
# Removal
# pattern assigned cluster: 106
# pattern iscore: False
# pattern neighbors: [637, 646, 753, 807, 857, 861, 982, 985]
# exists core point in the neighbors: False
# number of points in the cluster: 10
# vanish cluster ID: 106
# cluster points: {772, 646, 807, 733, 688, 976, 630, 857, 731, 985}
# [<Cluster.Cluster object at 0x7f21d7b6e898>, <Cluster.Cluster object at 0x7f224c0aaf28>, <Cluster.Cluster object at 0x7f21d7aa8d68>, <Cluster.Cluster object at 0x7f21d7aa8d30>, <Cluster.Cluster object at 0x7f21d7aa8dd8>, <Cluster.Cluster object at 0x7f21d7aa8e10>, <Cluster.Cluster object at 0x7f21d7aa8e48>, <Cluster.Cluster object at 0x7f21d7aa8e80>, <Cluster.Cluster object at 0x7f21d7aa8eb8>, <Cluster.Cluster object at 0x7f21d7aa8ef0>, <Cluster.Cluster object at 0x7f21d7aa8f28>, <Cluster.Cluster object at 0x7f21d7aa8f98>, <Cluster.Cluster object at 0x7f21d7aa8fd0>, <Cluster.Cluster object at 0x7f21d7a7d048>, <Cluster.Cluster object at 0x7f21d7a7d080>, <Cluster.Cluster object at 0x7f21d7a7d0b8>, <Cluster.Cluster object at 0x7f21d7a7d0f0>, <Cluster.Cluster object at 0x7f21d7a7d128>, <Cluster.Cluster object at 0x7f21d7a7d160>, <Cluster.Cluster object at 0x7f21d7a7d198>, <Cluster.Cluster object at 0x7f21d7a7d1d0>, <Cluster.Cluster object at 0x7f21d7a7d208>, <Cluster.Cluster object at 0x7f21d7a7d240>, <Cluster.Cluster object at 0x7f21d7a7d278>, <Cluster.Cluster object at 0x7f21d7a7d2e8>, <Cluster.Cluster object at 0x7f21d7a7d320>, <Cluster.Cluster object at 0x7f21d7a7d358>, <Cluster.Cluster object at 0x7f21d7a7d390>, <Cluster.Cluster object at 0x7f21d7a7d3c8>, <Cluster.Cluster object at 0x7f21d7a7d400>, <Cluster.Cluster object at 0x7f21d7a7d438>, <Cluster.Cluster object at 0x7f21d7a7d470>, <Cluster.Cluster object at 0x7f21d7a7d4a8>, <Cluster.Cluster object at 0x7f21d7a7d4e0>, <Cluster.Cluster object at 0x7f21d7a7d518>, <Cluster.Cluster object at 0x7f21d7a7d550>, <Cluster.Cluster object at 0x7f21d7a7d588>, <Cluster.Cluster object at 0x7f21d7a7d5c0>, <Cluster.Cluster object at 0x7f21d7a7d5f8>, <Cluster.Cluster object at 0x7f21d7a7d630>, <Cluster.Cluster object at 0x7f21d7a7d668>, <Cluster.Cluster object at 0x7f21d7a7d6a0>, <Cluster.Cluster object at 0x7f21d7a7d6d8>, <Cluster.Cluster object at 0x7f21d7a7d710>, <Cluster.Cluster object at 0x7f21d7a7d748>, <Cluster.Cluster object at 0x7f21d7a7d7b8>, <Cluster.Cluster object at 0x7f21d7a7d828>, <Cluster.Cluster object at 0x7f21d7a7d860>, <Cluster.Cluster object at 0x7f21d7a7d8d0>, <Cluster.Cluster object at 0x7f21d7a7d898>, <Cluster.Cluster object at 0x7f21d7a7d908>, <Cluster.Cluster object at 0x7f21d7a7d940>, <Cluster.Cluster object at 0x7f21d7a7d978>, <Cluster.Cluster object at 0x7f21d7a7d9b0>, <Cluster.Cluster object at 0x7f21d7a7d9e8>, <Cluster.Cluster object at 0x7f21d7a7da20>, <Cluster.Cluster object at 0x7f21d7a7da58>, <Cluster.Cluster object at 0x7f21d7a7da90>, <Cluster.Cluster object at 0x7f21d7a7dac8>, <Cluster.Cluster object at 0x7f21d7a7db00>, <Cluster.Cluster object at 0x7f21d7a7dba8>, <Cluster.Cluster object at 0x7f21d7a7d7f0>, <Cluster.Cluster object at 0x7f21d7a7dc50>, <Cluster.Cluster object at 0x7f21d7a7dc88>, <Cluster.Cluster object at 0x7f21d7a7dcc0>, <Cluster.Cluster object at 0x7f21d7a7dcf8>, <Cluster.Cluster object at 0x7f21d7a7dd30>, <Cluster.Cluster object at 0x7f21d7a7dd68>, <Cluster.Cluster object at 0x7f21d7a7dda0>, <Cluster.Cluster object at 0x7f21d7a7ddd8>, <Cluster.Cluster object at 0x7f21d7a7de10>, <Cluster.Cluster object at 0x7f21d7a7de48>, <Cluster.Cluster object at 0x7f21d7a7df98>, <Cluster.Cluster object at 0x7f21d7a7dfd0>, <Cluster.Cluster object at 0x7f21d7a86048>, <Cluster.Cluster object at 0x7f21d7a86080>, <Cluster.Cluster object at 0x7f21d7a860b8>, <Cluster.Cluster object at 0x7f21d7a860f0>, <Cluster.Cluster object at 0x7f21d7a86128>, <Cluster.Cluster object at 0x7f21d7a86160>, <Cluster.Cluster object at 0x7f21d7a86198>, <Cluster.Cluster object at 0x7f21d7a861d0>, <Cluster.Cluster object at 0x7f21d7a86208>, <Cluster.Cluster object at 0x7f21d7a86240>, <Cluster.Cluster object at 0x7f21d7a86278>, <Cluster.Cluster object at 0x7f21d7a7deb8>, <Cluster.Cluster object at 0x7f21d7a862b0>, <Cluster.Cluster object at 0x7f21d7a86320>, <Cluster.Cluster object at 0x7f21d7a86358>, <Cluster.Cluster object at 0x7f21d7a86390>, <Cluster.Cluster object at 0x7f21d7a863 ...
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# True
# cluster vanished!
# pattern ID: 630
#
#
# remove: 631
# Removal
#
# remove: 632
# Removal
#
# remove: 633
#
# Nonsplit Reduction
# assigned cluster: 107
#
# remove: 634
# Removal
# pattern assigned cluster: 56
# pattern iscore: False
# pattern neighbors: [824, 864, 902, 986, 988]
# exists core point in the neighbors: False
# number of points in the cluster: 9
# vanish cluster ID: 56
# cluster points: {902, 676, 678, 847, 977, 986, 988, 864, 634}
dcc0>, <Cluster.Cluster object at 0x7f21d7a7dcf8>, <Cluster.Cluster object at 0x7f21d7a7dd30>, <Cluster.Cluster object at 0x7f21d7a7dd68>, <Cluster.Cluster object at 0x7f21d7a7dda0>, <Cluster.Cluster object at 0x7f21d7a7ddd8>, <Cluster.Cluster object at 0x7f21d7a7de10>, <Cluster.Cluster object at 0x7f21d7a7de48>, <Cluster.Cluster object at 0x7f21d7a7df98>, <Cluster.Cluster object at 0x7f21d7a7dfd0>, <Cluster.Cluster object at 0x7f21d7a86048>, <Cluster.Cluster object at 0x7f21d7a86080>, <Cluster.Cluster object at 0x7f21d7a860b8>, <Cluster.Cluster object at 0x7f21d7a860f0>, <Cluster.Cluster object at 0x7f21d7a86128>, <Cluster.Cluster object at 0x7f21d7a86160>, <Cluster.Cluster object at 0x7f21d7a86198>, <Cluster.Cluster object at 0x7f21d7a861d0>, <Cluster.Cluster object at 0x7f21d7a86208>, <Cluster.Cluster object at 0x7f21d7a86240>, <Cluster.Cluster object at 0x7f21d7a86278>, <Cluster.Cluster object at 0x7f21d7a7deb8>, <Cluster.Cluster object at 0x7f21d7a862b0>, <Cluster.Cluster object at 0x7f21d7a86320>, <Cluster.Cluster object at 0x7f21d7a86358>, <Cluster.Cluster object at 0x7f21d7a86390>, <Cluster.Cluster object at 0x7f21d7a863 ...
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# cluster vanished!
# pattern ID: 634
#
#
# remove: 635
#
# Nonsplit Reduction
# assigned cluster: 107
#
# remove: 636
#
# Nonsplit Reduction
# assigned cluster: 107
#
# remove: 637
# Removal
#
# remove: 638
#
# Nonsplit Reduction
# assigned cluster: 107
#
# remove: 639
# Removal
# pattern assigned cluster: 84
# pattern iscore: False
# pattern neighbors: [668, 670, 687, 705, 811, 818, 822, 890, 993]
# exists core point in the neighbors: False
# number of points in the cluster: 8
# vanish cluster ID: 84
# cluster points: {668, 670, 818, 822, 705, 993, 890, 639}
# [<Cluster.Cluster object at 0x7f21d7b6e898>, <Cluster.Cluster object at 0x7f224c0aaf28>, <Cluster.Cluster object at 0x7f21d7aa8d68>, <Cluster.Cluster object at 0x7f21d7aa8d30>, <Cluster.Cluster object at 0x7f21d7aa8dd8>, <Cluster.Cluster object at 0x7f21d7aa8e10>, <Cluster.Cluster object at 0x7f21d7aa8e48>, <Cluster.Cluster object at 0x7f21d7aa8e80>, <Cluster.Cluster object at 0x7f21d7aa8eb8>, <Cluster.Cluster object at 0x7f21d7aa8ef0>, <Cluster.Cluster object at 0x7f21d7aa8f28>, <Cluster.Cluster object at 0x7f21d7aa8f98>, <Cluster.Cluster object at 0x7f21d7aa8fd0>, <Cluster.Cluster object at 0x7f21d7a7d048>, <Cluster.Cluster object at 0x7f21d7a7d080>, <Cluster.Cluster object at 0x7f21d7a7d0b8>, <Cluster.Cluster object at 0x7f21d7a7d0f0>, <Cluster.Cluster object at 0x7f21d7a7d128>, <Cluster.Cluster object at 0x7f21d7a7d160>, <Cluster.Cluster object at 0x7f21d7a7d198>, <Cluster.Cluster object at 0x7f21d7a7d1d0>, <Cluster.Cluster object at 0x7f21d7a7d208>, <Cluster.Cluster object at 0x7f21d7a7d240>, <Cluster.Cluster object at 0x7f21d7a7d278>, <Cluster.Cluster object at 0x7f21d7a7d2e8>, <
at 0x7f21d7a86240>, <Cluster.Cluster object at 0x7f21d7a86278>, <Cluster.Cluster object at 0x7f21d7a7deb8>, <Cluster.Cluster object at 0x7f21d7a862b0>, <Cluster.Cluster object at 0x7f21d7a86320>, <Cluster.Cluster object at 0x7f21d7a86358>, <Cluster.Cluster object at 0x7f21d7a86390>, <Cluster.Cluster object at 0x7f21d7a863 ...
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# cluster vanished!
# pattern ID: 639
#
#
# remove: 640
#
# Nonsplit Reduction
# assigned cluster: 107
#
# remove: 641
#
# Nonsplit Reduction
# assigned cluster: 107
#
# remove: 642
# Removal
#
# remove: 643
#
# Nonsplit Reduction
# assigned cluster: 107
#
# remove: 644
#
# Nonsplit Reduction
# assigned cluster: 107
#
# remove: 645
# Removal
#
# remove: 646
# Removal
#
# remove: 647
#
# Nonsplit Reduction
# assigned cluster: 107
#
# remove: 648
#
# Nonsplit Reduction
# assigned cluster: 107
#
# remove: 649
#
# Nonsplit Reduction
# assigned cluster: 107
#
# remove: 650
#
# Nonsplit Reduction
# assigned cluster: 107
#
# remove: 651
#
# Nonsplit Reduction
# assigned cluster: 107
#
# remove: 652
#
# Nonsplit Reduction
# assigned cluster: 107
#
# remove: 653
# Removal
#
# remove: 654
#
# Nonsplit Reduction
# assigned cluster: 107
#
# remove: 655
#
# Nonsplit Reduction
# assigned cluster: 107
#
# remove: 656
# Reduction
# assigned cluster: 107
#
# remove: 657
#
# Nonsplit Reduction
# assigned cluster: 107
#
# remove: 658
#
# Nonsplit Reduction
# assigned cluster: 107
#
# remove: 659
#
# Nonsplit Reduction
# assigned cluster: 107
#
# remove: 660
# Removal
#
# remove: 661
# Reduction
# assigned cluster: 107
#
# remove: 662
#
# Nonsplit Reduction
# assigned cluster: 107
#
# remove: 663
# Removal
#
# remove: 664
# Removal
#
# remove: 665
# Removal
#
# remove: 666
# Removal
#
# remove: 667
#
# Nonsplit Reduction
# assigned cluster: 107
#
# remove: 668
# Removal
#
# remove: 669
# Removal
#
# remove: 670
# Removal
#
# remove: 671
#
# Nonsplit Reduction
# assigned cluster: 107
#
# remove: 672
#
# Nonsplit Reduction
# assigned cluster: 107
#
# remove: 673
# Removal
#
# remove: 674
#
# Split
#
# remove: 675
#
# Nonsplit Reduction
# assigned cluster: 113
#
# remove: 676
# Removal
#
# remove: 677
# Reduction
# assigned cluster: 113
#
# remove: 678
# Removal
#
# remove: 679
# Removal
#
# remove: 680
# Removal
#
# remove: 681
# Reduction
# assigned cluster: 113
#
# remove: 682
#
# Nonsplit Reduction
# assigned cluster: 113
#
# remove: 683
# Removal
#
# remove: 684
#
# Nonsplit Reduction
# assigned cluster: 111
#
# remove: 685
# Removal
#
# remove: 686
#
# Nonsplit Reduction
# assigned cluster: 113
#
# remove: 687
# Removal
#
# remove: 688
# Removal
#
# remove: 689
#
# Nonsplit Reduction
# assigned cluster: 113
#
# remove: 690
# Removal
#
# remove: 691
#
# Nonsplit Reduction
# assigned cluster: 113
#
# remove: 692
# Removal
#
# remove: 693
#
# Nonsplit Reduction
# assigned cluster: 113
#
# remove: 694
#
# Nonsplit Reduction
# assigned cluster: 113
#
# remove: 695
#
# Nonsplit Reduction
# assigned cluster: 113
#
# remove: 696
# Reduction
# assigned cluster: 111
#
# remove: 697
# Removal
#
# remove: 698
# Removal
#
# remove: 699
#
# Nonsplit Reduction
# assigned cluster: 113
#
# Incremental DBSCAN Results
# ==========================
#
# Dataset has 1000 Points
# Cluster 1 has 129 Points
#
# Runtime = 4.168428659439087[sec]
# EPS = 0.3
# Minpts = 10

# %%
inc_labels = np.array(incDBSCAN.getLabels())
inc_n_clusters_ = len(set(inc_labels)) - (1 if -1 in inc_labels else 0)
inc_n_noise_ = list(inc_labels).count(-1)

# %%
len(inc_labels)
# Out:
# 300

# %%
fig = plt.figure(figsize=(12.0, 12.0))
inc_unique_labels = set(inc_labels)
colors = [plt.cm.Spectral(each) for each in np.linspace(0, 1, len(inc_unique_labels))]
for k, col in zip(inc_unique_labels, colors):
    if k == -1:
        # Black used for noise.
        col = [0, 0, 0, 1]

    inc_class_member_mask = inc_labels == k

    inc_xy = X_add[inc_class_member_mask]
    plt.plot(
        inc_xy[:, 0],
        inc_xy[:, 1],
        "o",
        markerfacecolor=tuple(col),
        markeredgecolor="k",
        markersize=8,
    )

plt.title("Estimated number of clusters: %d" % inc_n_clusters_)
plt.show()

# %%
inc_unique_labels
# Out:
# {-1, 111, 113}

# %%
inc_labels
# Out:
# array([ -1,  -1,  -1, 113,  -1,  -1, 113, 113,  -1, 113,  -1,  -1,  -1,
#        113,  -1, 113, 113,  -1, 111, 113,  -1,  -1, 111, 113, 113, 113,
#        113,  -1, 111, 113, 111,  -1,  -1,  -1,  -1, 111, 113,  -1,  -1,
#         -1, 111, 111, 113,  -1, 113, 111,  -1, 113, 111, 113, 113, 113,
#        113,  -1, 113,  -1,  -1, 113,  -1, 113,  -1,  -1,  -1, 113,  -1,
#        111, 113, 111,  -1,  -1, 113,  -1,  -1, 113, 111,  -1, 113,  -1,
#         -1,  -1, 113,  -1, 111, 113, 113, 113, 113,  -1, 111,  -1,  -1,
#         -1,  -1, 113,  -1, 113, 113, 113,  -1, 111, 113, 113, 111,  -1,
#        113, 113, 113,  -1, 113,  -1, 113,  -1, 113,  -1,  -1, 113,  -1,
#         -1,  -1,  -1, 111,  -1,  -1,  -1,  -1,  -1,  -1, 113, 111, 113,
#        113, 111, 113,  -1,  -1, 113,  -1,  -1,  -1, 113, 113, 113,  -1,
#        113,  -1,  -1,  -1,  -1,  -1, 113, 113, 113, 113, 113, 113, 113,
#        111,  -1, 113, 113, 113,  -1, 113,  -1,  -1, 113, 113, 113, 113,
#         -1,  -1,  -1, 111,  -1,  -1,  -1, 113, 113, 113, 113, 113, 111,
#        113,  -1, 113,  -1, 113, 113,  -1,  -1,  -1,  -1,  -1, 111, 113,
#        113, 111,  -1, 113, 113, 111,  -1,  -1, 113,  -1,  -1, 113, 113,
#        113,  -1,  -1, 113, 113,  -1, 113, 113,  -1,  -1, 113,  -1, 113,
#        113, 113, 113,  -1, 111,  -1, 113,  -1, 113, 113, 113,  -1,  -1,
#         -1, 111, 113, 113,  -1,  -1, 111, 113,  -1,  -1, 113, 113,  -1,
#        113, 113, 113, 111,  -1, 113, 111, 113, 113,  -1, 113, 113,  -1,
#        111, 111,  -1, 111,  -1, 113,  -1,  -1, 113, 111, 113, 113,  -1,
#        113, 113, 113,  -1,  -1,  -1, 113,  -1, 111,  -1, 113,  -1,  -1,
#         -1,  -1,  -1, 111, 113, 113, 113,  -1, 111, 113,  -1, 111, 113,
#        113])

# %%
fig = plt.figure(figsize=(12.0, 12.0))
inc_unique_labels = set(inc_labels)
colors = [plt.cm.Spectral(each) for each in np.linspace(0, 1, len(inc_unique_labels))]
for k, col in zip(inc_unique_labels, colors):
    if k == -1:
        # Black used for noise.
        col = [0, 0, 0, 1]

    inc_class_member_mask = inc_labels == k

    X_tmp = X_add[1:]
    inc_xy = X_tmp[inc_class_member_mask[1:]]
    plt.plot(
        inc_xy[:, 0],
        inc_xy[:, 1],
        "o",
        markerfacecolor=tuple(col),
        markeredgecolor="k",
        markersize=8,
    )

next_delete = X_add[0]
print(next_delete)
plt.plot(next_delete[0],
         next_delete[1],
         "o",
         markerfacecolor="g",
         markeredgecolor="k",
         markersize=8,)
    
plt.title("Estimated number of clusters: %d" % inc_n_clusters_)
plt.show()
# Out:
# [-1.45408484 -1.99716132]
